# %%
import pandas as pd

# %%
df = pd.read_html("https://finance.yahoo.com/quote/F/history?p=F")[0]

# %%
df.head(3)
# Out:
#            Date   Open   High   Low Close* Adj Close**     Volume
# 0  Jan 15, 2021  10.04  10.05  9.82   9.83        9.83   99914900
# 1  Jan 14, 2021   9.81  10.20  9.79  10.17       10.17  112695300
# 2  Jan 13, 2021   9.91   9.92  9.64   9.78        9.78   89549300

# %%
df.describe()
# Out:
#                 Date  Open  High   Low Close* Adj Close**    Volume
# count            101   101   101   101    101         101       101
# unique           101    81    81    82     83          83       101
# top     Aug 31, 2020  9.31  9.32  8.78   8.82        8.82  53761800
# freq               1     3     3     4      3           3         1

# %%
df = df.head(50).sort_values(by='Date')

# %%
df = df.drop([0, 32])

# %%
df = df.astype ({"Open":'float',
                 "High":'float',
                 "Low":'float',
                 "Close*":'float',
                 "Adj Close**":'float',
                 "Volume" :'float'})

# %%
df
# Out:
#             Date  Open   High   Low  Close*  Adj Close**       Volume
# 31  Dec 01, 2020  9.16   9.40  9.16    9.24         9.24   68970300.0
# 30  Dec 02, 2020  9.16   9.24  9.08    9.20         9.20   48345000.0
# 29  Dec 03, 2020  9.26   9.32  9.15    9.21         9.21   50302100.0
# 28  Dec 04, 2020  9.26   9.44  9.24    9.34         9.34   48775500.0
# 27  Dec 07, 2020  9.31   9.33  9.15    9.22         9.22   58305200.0
# 26  Dec 08, 2020  9.19   9.33  9.17    9.25         9.25   56296700.0
# 25  Dec 09, 2020  9.31   9.49  9.29    9.45         9.45   60780300.0
# 24  Dec 10, 2020  9.31   9.32  9.10    9.12         9.12   83372800.0
# 23  Dec 11, 2020  9.19   9.19  9.01    9.02         9.02   73438200.0
# 22  Dec 14, 2020  9.13   9.18  8.88    8.91         8.91   76826000.0
# 21  Dec 15, 2020  9.03   9.15  8.94    9.15         9.15   69665900.0
# 20  Dec 16, 2020  9.17   9.18  8.97    9.04         9.04   55274500.0
# ...

# %%
df.describe()
# Out:
#             Open       High        Low     Close*  Adj Close**        Volume
# count  48.000000  48.000000  48.000000  48.000000    48.000000  4.800000e+01
# mean    8.898333   9.023750   8.784583   8.910417     8.910417  6.782910e+07
# std     0.439373   0.449788   0.447156   0.474687     0.474687  2.162257e+07
# min     7.760000   7.870000   7.630000   7.640000     7.640000  2.785390e+07
# 25%     8.805000   8.850000   8.667500   8.780000     8.780000  5.329305e+07
# 50%     8.935000   9.040000   8.815000   8.920000     8.920000  6.814855e+07
# 75%     9.162500   9.267500   9.042500   9.162500     9.162500  7.987255e+07
# max     9.910000  10.200000   9.790000  10.170000    10.170000  1.248085e+08

# %%
df.corr()
# Out:
#                  Open      High       Low    Close*  Adj Close**    Volume
# Open         1.000000  0.954594  0.977427  0.926622     0.926622  0.051866
# High         0.954594  1.000000  0.976968  0.987268     0.987268  0.222748
# Low          0.977427  0.976968  1.000000  0.971545     0.971545  0.057488
# Close*       0.926622  0.987268  0.971545  1.000000     1.000000  0.194933
# Adj Close**  0.926622  0.987268  0.971545  1.000000     1.000000  0.194933
# Volume       0.051866  0.222748  0.057488  0.194933     0.194933  1.000000

# %%
df['Gain'] = df['Close*']- df['Open']

# %%
df
# Out:
#             Date  Open   High   Low  Close*  Adj Close**       Volume  Gain
# 31  Dec 01, 2020  9.16   9.40  9.16    9.24         9.24   68970300.0  0.08
# 30  Dec 02, 2020  9.16   9.24  9.08    9.20         9.20   48345000.0  0.04
# 29  Dec 03, 2020  9.26   9.32  9.15    9.21         9.21   50302100.0 -0.05
# 28  Dec 04, 2020  9.26   9.44  9.24    9.34         9.34   48775500.0  0.08
# 27  Dec 07, 2020  9.31   9.33  9.15    9.22         9.22   58305200.0 -0.09
# 26  Dec 08, 2020  9.19   9.33  9.17    9.25         9.25   56296700.0  0.06
# 25  Dec 09, 2020  9.31   9.49  9.29    9.45         9.45   60780300.0  0.14
# 24  Dec 10, 2020  9.31   9.32  9.10    9.12         9.12   83372800.0 -0.19
# 23  Dec 11, 2020  9.19   9.19  9.01    9.02         9.02   73438200.0 -0.17
# 22  Dec 14, 2020  9.13   9.18  8.88    8.91         8.91   76826000.0 -0.22
# 21  Dec 15, 2020  9.03   9.15  8.94    9.15         9.15   69665900.0  0.12
# ...
