# %% [markdown]
# # Examen de Introduccion a Big Data segundo parcial

# %% [markdown]
# ## Librerias necesarias

# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np
import seaborn as sns

# %%
amz_reviews = pd.read_csv('https://testutmjonathan.s3.amazonaws.com/data.csv')

# %% [markdown]
# ##  Primeros 10 artistas ordenados alfabeticamente

# %%
artist = amz_reviews.sort_values('artists', ascending=True)

# %%
artist.head(10)
# Out:
#         acousticness                                            artists  \
# 107980       0.84800  ["'In The Heights' Original Broadway Company",...
# 87166        0.06060                                   ["'Til Tuesday"]
# 12910        0.02820                                   ["'Til Tuesday"]
# 151863       0.09890                                   ["'Til Tuesday"]
# 151760       0.20700                                   ["'Til Tuesday"]
# 86093        0.00336                                   ["'Til Tuesday"]
# 32430        0.00339                                   ["'Til Tuesday"]
# 167074       0.26200                                   ["'Til Tuesday"]
# 51574        0.18100                                   ["'Til Tuesday"]
# 166405       0.68200                  ["100 First Songs' Participants"]
#
#         danceability  duration_ms  energy  explicit                      id  \
# 107980         0.397       244067   0.242         0  6OSTrvIX8JXxRxFT4C9y0J
# ...

# %%
relacion = amz_reviews[['artists']]

# %%
relacion.head(10)
# Out:
#                              artists
# 0                    ['Mamie Smith']
# 1          ["Screamin' Jay Hawkins"]
# 2                    ['Mamie Smith']
# 3                ['Oscar Velazquez']
# 4                           ['Mixe']
# 5  ['Mamie Smith & Her Jazz Hounds']
# 6                    ['Mamie Smith']
# 7  ['Mamie Smith & Her Jazz Hounds']
# 8               ['Francisco Canaro']
# 9                         ['Meetya']

# %% [markdown]
# ## Datos ordenados alfabeticamente

# %%
orden_alf = amz_reviews.head(10).sort_values('artists', ascending=True)

# %%
orden_alf['artists']
# Out:
# 1            ["Screamin' Jay Hawkins"]
# 8                 ['Francisco Canaro']
# 5    ['Mamie Smith & Her Jazz Hounds']
# 7    ['Mamie Smith & Her Jazz Hounds']
# 0                      ['Mamie Smith']
# 2                      ['Mamie Smith']
# 6                      ['Mamie Smith']
# 9                           ['Meetya']
# 4                             ['Mixe']
# 3                  ['Oscar Velazquez']
# Name: artists, dtype: object

# %% [markdown]
# ## Posibles datos a relacionar

# %%
amz_reviews.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 174389 entries, 0 to 174388
# Data columns (total 19 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   acousticness      174389 non-null  float64
#  1   artists           174389 non-null  object
#  2   danceability      174389 non-null  float64
#  3   duration_ms       174389 non-null  int64
#  4   energy            174389 non-null  float64
#  5   explicit          174389 non-null  int64
#  6   id                174389 non-null  object
#  7   instrumentalness  174389 non-null  float64
#  8   key               174389 non-null  int64
#  9   liveness          174389 non-null  float64
#  10  loudness          174389 non-null  float64
#  11  mode              174389 non-null  int64
#  12  name              174389 non-null  object
#  13  popularity        174389 non-null  int64
#  14  release_date      174389 non-null  object
#  15  speechiness       174389 non-null  float64
# ...

# %%
amz_reviews.columns
# Out:
# Index(['acousticness', 'artists', 'danceability', 'duration_ms', 'energy',
#        'explicit', 'id', 'instrumentalness', 'key', 'liveness', 'loudness',
#        'mode', 'name', 'popularity', 'release_date', 'speechiness', 'tempo',
#        'valence', 'year'],
#       dtype='object')

# %% [markdown]
# ## Datos ya relacionados

# %%
relacion = amz_reviews[['id','artists','danceability','popularity']]

# %%
relacion.head(10)
# Out:
#                        id                            artists  danceability  \
# 0  0cS0A1fUEUd1EW3FcF8AEI                    ['Mamie Smith']         0.598
# 1  0hbkKFIJm7Z05H8Zl9w30f          ["Screamin' Jay Hawkins"]         0.852
# 2  11m7laMUgmOKqI3oYzuhne                    ['Mamie Smith']         0.647
# 3  19Lc5SfJJ5O1oaxY0fpwfh                ['Oscar Velazquez']         0.730
# 4  2hJjbsLCytGsnAHfdsLejp                           ['Mixe']         0.704
# 5  3HnrHGLE9u2MjHtdobfWl9  ['Mamie Smith & Her Jazz Hounds']         0.424
# 6  5DlCyqLyX2AOVDTjjkDZ8x                    ['Mamie Smith']         0.782
# 7  02FzJbHtqElixxCmrpSCUa  ['Mamie Smith & Her Jazz Hounds']         0.474
# 8  02i59gYdjlhBmbbWhf8YuK               ['Francisco Canaro']         0.469
# 9  06NUxS2XL3efRh0bloxkHm                         ['Meetya']         0.571
#
#    popularity
# 0          12
# 1           7
# 2           4
# 3          17
# 4           2
# 5           9
# 6           5
# 7           0
# ...

# %% [markdown]
# # Media, Promedio, Varianza, Valor Minimo, Valor Maximo

# %% [markdown]
# ## Todo el csv

# %%
amz_reviews.describe()
# Out:
#         acousticness   danceability   duration_ms         energy  \
# count  174389.000000  174389.000000  1.743890e+05  174389.000000
# mean        0.499228       0.536758  2.328100e+05       0.482721
# std         0.379936       0.176025  1.483958e+05       0.272685
# min         0.000000       0.000000  4.937000e+03       0.000000
# 25%         0.087700       0.414000  1.661330e+05       0.249000
# 50%         0.517000       0.548000  2.057870e+05       0.465000
# 75%         0.895000       0.669000  2.657200e+05       0.711000
# max         0.996000       0.988000  5.338302e+06       1.000000
#
#             explicit  instrumentalness            key       liveness  \
# count  174389.000000     174389.000000  174389.000000  174389.000000
# mean        0.068135          0.197252       5.205305       0.211123
# std         0.251978          0.334574       3.518292       0.180493
# min         0.000000          0.000000       0.000000       0.000000
# ...

# %% [markdown]
# ## Nuestra anterior relacion

# %%
relacion.describe()
# Out:
#         danceability     popularity
# count  174389.000000  174389.000000
# mean        0.536758      25.693381
# std         0.176025      21.872740
# min         0.000000       0.000000
# 25%         0.414000       1.000000
# 50%         0.548000      25.000000
# 75%         0.669000      42.000000
# max         0.988000     100.000000

# %%
varianza = amz_reviews.var()

# %%
print(varianza)
# Out:
# acousticness        1.443512e-01
# danceability        3.098489e-02
# duration_ms         2.202131e+10
# energy              7.435737e-02
# explicit            6.349301e-02
# instrumentalness    1.119396e-01
# key                 1.237838e+01
# liveness            3.257762e-02
# loudness            3.239421e+01
# mode                2.090420e-01
# popularity          4.784167e+02
# speechiness         3.321877e-02
# tempo               9.153153e+02
# valence             6.994798e-02
# year                7.240378e+02
# dtype: float64

# %% [markdown]
# # Pregunta

# %% [markdown]
# ### ¿Cuales valores pueden tener una relacion lineal positiva, demuestre y diga el porque lo consideran asi?

# %%
##Los de danceability y duration ms ya que estos estan definidos por numeros y aunmentan y disminuyen de manera simultanea por lo cual puede tener una relacon lineal

# %%
sns.pairplot(relacion, kind ='reg')
